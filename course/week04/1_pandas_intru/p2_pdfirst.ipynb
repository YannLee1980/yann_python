# %%
import pandas as pd
import numpy as np
import os

# %%
pwd = os.path.dirname(os.path.realpath('__file__'))
pwd
# Out:
# '/Users/yannlee/codes/GeekBang_Train/yann_python/course/week04/1_pandas_intru'

# %%
book = os.path.join(pwd, 'book_utf8.csv')
book
# Out:
# '/Users/yannlee/codes/GeekBang_Train/yann_python/course/week04/1_pandas_intru/book_utf8.csv'

# %%
df = pd.read_csv(book, header=None)
df.columns = ['star', 'vote', 'shorts']
df
# Out:
#     star  vote                                             shorts
# 0     还行    13  とある科学の電磁砲。《禁忌魔术》中短篇《猛射》扩写的长篇，太单薄了。东野说这篇的汤川学是神探...
# 1     较差    10                 我们阿东开始炒冷饭了吗？把《禁忌魔术》中的短篇《猛射》拉长了写。。。
# 2     还行     5                        其实就是《猛射》，原封不动地。看了才发现又重看了一次。
# 3     力荐     5   东野圭吾说这本书里的汤川是整个伽利略系列里最优秀的，我倒觉得是整个系列里情商最上线、最聪明的一次
# 4     还行     3  作为扩写还是蛮成功的，本来点子就很赞，只写个短篇浪费了，长篇把相关人员的行为逻辑描写的更充分...
# ..   ...   ...                                                ...
# 576   较差     0                             感觉像是什么有教育意义的故事，并不像推理（。
# 577   还行     0                50页的短篇写成300页的长篇，东野老贼也网文化了，昏昏欲睡的一本小说
# 578   力荐     0  本来看着这个书名和开头的内容一点点引人入胜，是不错的题材，但最后结局没有任何新意，没有灵魂的...
# 579   推荐     1  书写的很好啦，但单单把禁忌魔术最后一个短篇拿出来，还扩写了，这个是神马操作？？？！！！真心好...
# 580   力荐     0  科学技术是双刃剑呀，关键在于使用者。\r\n秋惠是个迷，大贺心狠，汤川是个以德以情教化学生的...
#
# [581 rows x 3 columns]

# %%
# 显示特定的行、列
df.loc[13:17, ['shorts', 'vote']]
# Out:
#                                                shorts  vote
# 13  案件真是乏善可陈，酒店意外死亡的梗说实话森村诚一在《人类的天敌》里面早就写过了。感觉东野真的...     0
# 14                                        非常非常非常平庸的作品     2
# 15  好久不见的神探伽利略系列！汤川学的案子。熟悉的多线汇聚的故事，层层递进，非常精彩，三个小时的...     2
# 16  撇开短篇扩成长篇不说，这部感觉很一般，汤川就是我认识的汤川，他的行为就是东野一直描摹的那种个...     0
# 17        汤川教授最感性的一次吧。为了不违背枪支管理法而想出这么理工科的高威力杀人装置也是厉害。     1

# %%
df.iloc[:3, :2]
# Out:
#   star  vote
# 0   还行    13
# 1   较差    10
# 2   还行     5

# %%
df['star'] == '力荐'
# Out:
# 0      False
# 1      False
# 2      False
# 3       True
# 4      False
#        ...
# 576    False
# 577    False
# 578     True
# 579    False
# 580     True
# Name: star, Length: 581, dtype: bool

# %%
# 过滤数据
df[df['star'] == '力荐']
# Out:
#     star  vote                                             shorts
# 3     力荐     5   东野圭吾说这本书里的汤川是整个伽利略系列里最优秀的，我倒觉得是整个系列里情商最上线、最聪明的一次
# 12    力荐     1        这本书的主题是传承。一个让东野念念不忘的故事，日本人更能理解的坚持与决绝，与诡计无关。
# 56    力荐     0       其实就是《禁忌魔术》小说集里的最后一篇《猛射》，多线汇聚层层递进的老套路，总体乏善可陈…
# 61    力荐     0  不想给他打低分，我比较喜欢汤川学…感觉自己的知识面有点窄，搞清楚了谁是凶手，却没搞清楚手法…...
# 562   力荐     0                                          湯川學！！有血有肉
# 578   力荐     0  本来看着这个书名和开头的内容一点点引人入胜，是不错的题材，但最后结局没有任何新意，没有灵魂的...
# 580   力荐     0  科学技术是双刃剑呀，关键在于使用者。\r\n秋惠是个迷，大贺心狠，汤川是个以德以情教化学生的...

# %%
df.dropna()
# Out:
#     star  vote                                             shorts
# 0     还行    13  とある科学の電磁砲。《禁忌魔术》中短篇《猛射》扩写的长篇，太单薄了。东野说这篇的汤川学是神探...
# 1     较差    10                 我们阿东开始炒冷饭了吗？把《禁忌魔术》中的短篇《猛射》拉长了写。。。
# 2     还行     5                        其实就是《猛射》，原封不动地。看了才发现又重看了一次。
# 3     力荐     5   东野圭吾说这本书里的汤川是整个伽利略系列里最优秀的，我倒觉得是整个系列里情商最上线、最聪明的一次
# 4     还行     3  作为扩写还是蛮成功的，本来点子就很赞，只写个短篇浪费了，长篇把相关人员的行为逻辑描写的更充分...
# ..   ...   ...                                                ...
# 576   较差     0                             感觉像是什么有教育意义的故事，并不像推理（。
# 577   还行     0                50页的短篇写成300页的长篇，东野老贼也网文化了，昏昏欲睡的一本小说
# 578   力荐     0  本来看着这个书名和开头的内容一点点引人入胜，是不错的题材，但最后结局没有任何新意，没有灵魂的...
# 579   推荐     1  书写的很好啦，但单单把禁忌魔术最后一个短篇拿出来，还扩写了，这个是神马操作？？？！！！真心好...
# 580   力荐     0  科学技术是双刃剑呀，关键在于使用者。\r\n秋惠是个迷，大贺心狠，汤川是个以德以情教化学生的...
#
# [581 rows x 3 columns]

# %%
# 数据聚合
df.groupby('star').sum()
# Out:
#       vote
# star
# 力荐       7
# 很差       2
# 推荐       3
# 较差      14
# 还行      37

# %%
# 创建新列
star_to_number = {
    '力荐' : 5,
    '推荐' : 4,
    '还行' : 3,
    '较差' : 2,
    '很差' : 1
}
df['new_star'] = df['star'].map(star_to_number)
df
# Out:
#     star  vote                                             shorts  new_star
# 0     还行    13  とある科学の電磁砲。《禁忌魔术》中短篇《猛射》扩写的长篇，太单薄了。东野说这篇的汤川学是神探...         3
# 1     较差    10                 我们阿东开始炒冷饭了吗？把《禁忌魔术》中的短篇《猛射》拉长了写。。。         2
# 2     还行     5                        其实就是《猛射》，原封不动地。看了才发现又重看了一次。         3
# 3     力荐     5   东野圭吾说这本书里的汤川是整个伽利略系列里最优秀的，我倒觉得是整个系列里情商最上线、最聪明的一次         5
# 4     还行     3  作为扩写还是蛮成功的，本来点子就很赞，只写个短篇浪费了，长篇把相关人员的行为逻辑描写的更充分...         3
# ..   ...   ...                                                ...       ...
# 576   较差     0                             感觉像是什么有教育意义的故事，并不像推理（。         2
# 577   还行     0                50页的短篇写成300页的长篇，东野老贼也网文化了，昏昏欲睡的一本小说         3
# 578   力荐     0  本来看着这个书名和开头的内容一点点引人入胜，是不错的题材，但最后结局没有任何新意，没有灵魂的...         5
# 579   推荐     1  书写的很好啦，但单单把禁忌魔术最后一个短篇拿出来，还扩写了，这个是神马操作？？？！！！真心好...         4
# 580   力荐     0  科学技术是双刃剑呀，关键在于使用者。\r\n秋惠是个迷，大贺心狠，汤川是个以德以情教化学生的...         5
#
# [581 rows x 4 columns]
